# %%
import numpy as np
import matplotlib.pyplot as plt
x_pos=0
y_pos=0
x_direct=1
y_direct=1
fig,ax=plt.subplots(figsize=(12,7))
ax.quiver(x_pos,y_pos,x_direct,y_direct)
ax.set_title('Queue plot with one arrow')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x_pos=0
y_pos=0
x_direct=-1
y_direct=-1
fig,ax=plt.subplots(figsize=(12,7))
ax.quiver(x_pos,y_pos,x_direct,y_direct)
ax.set_title('Quiver plot with one arrow')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create grid coordinates
x = np.linspace(-2, 2, 10)
y = np.linspace(-2, 2, 10)
X, Y = np.meshgrid(x, y)

# Define vector components for converging flow pattern
U = -X
V = Y

# Create quiver plot
plt.figure()
plt.title('Quiver Plot with Converging Flow Pattern')
plt.quiver(X, Y, U, V)
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x_pos=0
y_pos=0
x_direct=-1
y_direct=-500
fig,ax=plt.subplots(figsize=(12,7))
ax.quiver(x_pos,y_pos,x_direct,y_direct)
ax.set_title('Quiver plot with one arrow')
plt.show()
